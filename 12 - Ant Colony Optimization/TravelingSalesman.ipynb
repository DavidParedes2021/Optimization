# %% [markdown]
# # Problema del Traveling Salesman
#
# ## David Omar Paredes Paredes y Abraham Maximiliano Ávalos Corrales

# %%
import numpy             as np
import ACO               as ac
import matplotlib.pyplot as plt

# %%
TEST_POINTS = 'test_points.csv'

try:
	print('Loading points...')
	points = np.loadtxt(TEST_POINTS, delimiter=',')
except FileNotFoundError:
	print('Load failed!, no points')
	points = np.random.rand(15, 2) * 10
	print('Saving points....')
	np.savetxt(TEST_POINTS, points, delimiter=',')
print(points)
# Out:
# Loading points...
# [[6.02339741 1.01677479]
#  [1.89995108 2.83677664]
#  [9.53536077 2.0902643 ]
#  [8.10087137 0.04279019]
#  [0.54705415 6.21207967]
#  [0.81596031 3.70097539]
#  [3.7288328  3.30761811]
#  [1.7632499  2.56468789]
#  [5.88785735 4.35590638]
#  [9.67615191 1.25876657]
#  [1.78560654 6.7890298 ]
#  [7.46186111 9.01601552]
#  [5.75648694 1.70926969]
#  [4.49936371 1.73948949]
#  [2.53218212 5.86207262]]

# %%
plt.scatter(points[:, 0], points[:, 1])
